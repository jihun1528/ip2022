# %%
if x == 3:
  print "X equals 3."
elif x == 2:
  print "X equals 2."
else:
  print "X equals something else."
print "This is outside the 'if'."
# Out:
#   File "<ipython-input-2-c45685adeb51>", line 3
#     print "X equals 3."
#                       ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("X equals 3.")?

# %%
x = 3
while x < 5:
  print x, "still in the loop"
  x = x + 1 
3 still in the loop
4 still in the loop
x = 6
while x < 5:
  print x, "still in the loop"
# Out:
#   File "<ipython-input-6-b8a79c663696>", line 3
#     print x, "still in the loop"
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(x, "still in the loop")?
